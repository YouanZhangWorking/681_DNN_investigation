# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred_tflite import SSD
import matplotlib.pyplot as plt


if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    # dir_origin_path= "img/"  # 指定了用于检测的图片的文件夹路径
    # dir_save_path = "img_out/"  # 指定了检测完图片的保存路径
    # pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/hand/VOCdevkit/VOC2007/JPEGImages/230315_153921_00145.jpg"
    # pred_img_path = "/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand/img/240719_103320_00000slice.png"
    # pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/good/VOCdevkit/VOC2007/JPEGImages/230317_110146_00000.jpg"
    pred_img_path = r"/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/img/241009_192057_00014.png"
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            # r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()

# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred_tflite import SSD
import matplotlib.pyplot as plt

if __name__ == "__main__":
    # ssd = SSD(
    #     model_path ='/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand/output/20240228/hand_detection_20240228.h5',
    #     classes_path ='/home/zhangyouan/桌面/zya/dataset/681/hand/VOCdevkit/voc_classes.txt',
    # )
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    # dir_origin_path= "img/"  # 指定了用于检测的图片的文件夹路径
    # dir_save_path = "img_out/"  # 指定了检测完图片的保存路径
    # pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/good/VOCdevkit/VOC2007/JPEGImages/230317_111146_00616.jpg"
    pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/VOCdevkit/VOC2007/JPEGImages/240809_151110_00121.png"
    
    # if mode == "predict":
    #     img = pred_img_path
    #     try:
    #         image = Image.open(img)
    #     except:
    #         print('Open Error! Try again!')
    #     else:
    #         r_image = ssd.detect_image(image, crop=crop, count=count)
    #         r_image.show()
    #         r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
    
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()

# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred_tflite import SSD
import matplotlib.pyplot as plt

if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/good/VOCdevkit/VOC2007/JPEGImages/230317_111146_00616.jpg"
    
    # if mode == "predict":
    #     img = pred_img_path
    #     try:
    #         image = Image.open(img)
    #     except:
    #         print('Open Error! Try again!')
    #     else:
    #         r_image = ssd.detect_image(image, crop=crop, count=count)
    #         r_image.show()
    #         r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
    
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()

# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred_tflite import SSD
import matplotlib.pyplot as plt


if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    # pred_img_path = r"/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/img/240830_102910_00001.png"
    # pred_img_path = r"/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/img/240830_102917_00020.png"
    # pred_img_path = r"/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/img/240229_135220_00242.png"
    # pred_img_path = r"/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/img/240930_172329_00038.png"
    pred_img_path = r"/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/img/240930_172451_00063.png"
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            plt.imshow(img)
            plt.show()
# Out:
# 2025-10-10 16:33:45.665499: W tensorflow/c/c_api.cc:304] Operation '{name:'batch_normalization_110/beta/Assign' id:22892 op device:{requested: '', assigned: ''} def:{{{node batch_normalization_110/beta/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](batch_normalization_110/beta, batch_normalization_110/beta/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ...
