# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred_tflite import SSD
import matplotlib.pyplot as plt


if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    # dir_origin_path= "img/"  # 指定了用于检测的图片的文件夹路径
    # dir_save_path = "img_out/"  # 指定了检测完图片的保存路径
    # pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/hand/VOCdevkit/VOC2007/JPEGImages/230315_153921_00145.jpg"
    # pred_img_path = "/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand/img/240719_103320_00000slice.png"
    # pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/good/VOCdevkit/VOC2007/JPEGImages/230317_110146_00000.jpg"
    pred_img_path = r"/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/img/241009_192057_00014.png"
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            # r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()
# Out:
# 2024-11-21 11:37:26.817774: W tensorflow/c/c_api.cc:304] Operation '{name:'Conv2D_layer8_1/bias/Assign' id:3241 op device:{requested: '', assigned: ''} def:{{{node Conv2D_layer8_1/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](Conv2D_layer8_1/bias, Conv2D_layer8_1/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5|
# |             classes_path | /home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/voc_classes.txt|
# |              input_shape |                               [120, 160]|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |              [32, 59, 86, 113, 141, 168]|
# |          letterbox_image |                                    False|
# ----------------------------------------------------------------------
# /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-11-21 11:37:27.124754: W tensorflow/c/c_api.cc:304] Operation '{name:'predictions_1/concat' id:4961 op device:{requested: '', assigned: ''} def:{{{node predictions_1/concat}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32, _has_manual_control_dependencies=true](mbox_loc_final_1/Reshape, cls_conf_final_1/Softmax, predictions_1/concat/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# b'pc_screen 0.98' 32 74 86 109
# <class 'PIL.PngImagePlugin.PngImageFile'>

# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred_tflite import SSD
import matplotlib.pyplot as plt

if __name__ == "__main__":
    # ssd = SSD(
    #     model_path ='/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand/output/20240228/hand_detection_20240228.h5',
    #     classes_path ='/home/zhangyouan/桌面/zya/dataset/681/hand/VOCdevkit/voc_classes.txt',
    # )
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    # dir_origin_path= "img/"  # 指定了用于检测的图片的文件夹路径
    # dir_save_path = "img_out/"  # 指定了检测完图片的保存路径
    # pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/good/VOCdevkit/VOC2007/JPEGImages/230317_111146_00616.jpg"
    pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/VOCdevkit/VOC2007/JPEGImages/240809_151110_00121.png"
    
    # if mode == "predict":
    #     img = pred_img_path
    #     try:
    #         image = Image.open(img)
    #     except:
    #         print('Open Error! Try again!')
    #     else:
    #         r_image = ssd.detect_image(image, crop=crop, count=count)
    #         r_image.show()
    #         r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
    
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()
# Out:
# 2025-01-09 20:15:53.951273: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-09 20:15:53.978848: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-09 20:15:53.979306: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-09 20:15:54.531255: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py:883: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2025-01-09 20:15:56.694066: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2025-01-09 20:15:56.808376: W tensorflow/c/c_api.cc:304] Operation '{name:'DepthWiseConv2D_layer17/bias/Assign' id:1249 op device:{requested: '', assigned: ''} def:{{{node DepthWiseConv2D_layer17/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](DepthWiseConv2D_layer17/bias, DepthWiseConv2D_layer17/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5|
# |             classes_path | /home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/voc_classes.txt|
# |              input_shape |                               [120, 160]|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |              [32, 59, 86, 113, 141, 168]|
# |          letterbox_image |                                    False|
# ----------------------------------------------------------------------
# <class 'PIL.PngImagePlugin.PngImageFile'>
# /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-09 20:15:57.037569: W tensorflow/c/c_api.cc:304] Operation '{name:'predictions/concat' id:2215 op device:{requested: '', assigned: ''} def:{{{node predictions/concat}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32, _has_manual_control_dependencies=true](mbox_loc_final/Reshape, cls_conf_final/Softmax, predictions/concat/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred_tflite import SSD
import matplotlib.pyplot as plt

if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/good/VOCdevkit/VOC2007/JPEGImages/230317_111146_00616.jpg"
    
    # if mode == "predict":
    #     img = pred_img_path
    #     try:
    #         image = Image.open(img)
    #     except:
    #         print('Open Error! Try again!')
    #     else:
    #         r_image = ssd.detect_image(image, crop=crop, count=count)
    #         r_image.show()
    #         r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
    
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()
# Out:
# 2025-01-10 15:11:54.823343: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-10 15:11:54.851253: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-01-10 15:11:54.851714: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-10 15:11:55.402276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py:883: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2025-01-10 15:11:57.568488: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2025-01-10 15:11:57.689005: W tensorflow/c/c_api.cc:304] Operation '{name:'Conv2D_loc_DD2_2/bias/Assign' id:1837 op device:{requested: '', assigned: ''} def:{{{node Conv2D_loc_DD2_2/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](Conv2D_loc_DD2_2/bias, Conv2D_loc_DD2_2/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5|
# |             classes_path | /home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/voc_classes.txt|
# |              input_shape |                               [120, 160]|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |              [32, 59, 86, 113, 141, 168]|
# |          letterbox_image |                                    False|
# ----------------------------------------------------------------------
# /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2025-01-10 15:11:57.927043: W tensorflow/c/c_api.cc:304] Operation '{name:'predictions/concat' id:2215 op device:{requested: '', assigned: ''} def:{{{node predictions/concat}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32, _has_manual_control_dependencies=true](mbox_loc_final/Reshape, cls_conf_final/Softmax, predictions/concat/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
