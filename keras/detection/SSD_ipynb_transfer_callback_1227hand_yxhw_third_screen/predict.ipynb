# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred import SSD
import matplotlib.pyplot as plt


if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    # dir_origin_path= "img/"  # 指定了用于检测的图片的文件夹路径
    # dir_save_path = "img_out/"  # 指定了检测完图片的保存路径
    # pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/hand/VOCdevkit/VOC2007/JPEGImages/230315_153921_00145.jpg"
    # pred_img_path = "/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand/img/240719_103320_00000slice.png"
    # pred_img_path = "/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/img/241009_192057_00014.png"
    pred_img_path = r"/home/zhangyouan/桌面/zya/dataset/681/Book_PC_1206_crop/VOC2007/JPEGImages/241206_112258_00117.png"
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            # r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()
# Out:
# 2024-12-27 16:24:52.743482: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-27 16:24:52.771443: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-27 16:24:52.771876: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-27 16:24:53.335661: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING:tensorflow:From /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/layers/normalization/batch_normalization.py:883: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 2024-12-27 16:24:56.360409: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2024-12-27 16:24:56.556278: W tensorflow/c/c_api.cc:304] Operation '{name:'DepthwiseConv2D_loc_DD2_1/bias/Assign' id:3106 op device:{requested: '', assigned: ''} def:{{{node DepthwiseConv2D_loc_DD2_1/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](DepthwiseConv2D_loc_DD2_1/bias, DepthwiseConv2D_loc_DD2_1/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:56.902621: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_2/shape' id:3087 op device:{requested: '', assigned: ''} def:{{{node Reshape_2/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 480 2>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:57.030939: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_4/shape' id:3236 op device:{requested: '', assigned: ''} def:{{{node Reshape_4/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 120 2>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:57.160649: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_6/shape' id:3385 op device:{requested: '', assigned: ''} def:{{{node Reshape_6/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 36 2>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:57.286543: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_8/shape' id:3534 op device:{requested: '', assigned: ''} def:{{{node Reshape_8/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 6 2>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:57.415700: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_1/shape' id:3036 op device:{requested: '', assigned: ''} def:{{{node Reshape_1/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 600 4>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:57.542252: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_3/shape' id:3185 op device:{requested: '', assigned: ''} def:{{{node Reshape_3/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 480 4>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:57.671256: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_5/shape' id:3334 op device:{requested: '', assigned: ''} def:{{{node Reshape_5/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 120 4>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:57.799753: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_7/shape' id:3483 op device:{requested: '', assigned: ''} def:{{{node Reshape_7/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 36 4>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2024-12-27 16:24:57.930327: W tensorflow/c/c_api.cc:304] Operation '{name:'Reshape_9/shape' id:3632 op device:{requested: '', assigned: ''} def:{{{node Reshape_9/shape}} = Const[_has_manual_control_dependencies=true, dtype=DT_INT32, value=Tensor<type: int32 shape: [3] values: -1 6 4>]()}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/book_PICO/20241227_book_pico.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/book_PICO/20241227_book_pico.h5|
# |             classes_path | /home/zhangyouan/桌面/zya/dataset/681/Book_PC_1206_crop/VOC2007/voc_classes.txt|
# |              input_shape |                               [120, 160]|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |              [32, 59, 86, 113, 141, 168]|
# |          letterbox_image |                                    False|
# ----------------------------------------------------------------------
# /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-12-27 16:24:58.647119: W tensorflow/c/c_api.cc:304] Operation '{name:'predictions/concat' id:3951 op device:{requested: '', assigned: ''} def:{{{node predictions/concat}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32, _has_manual_control_dependencies=true](mbox_loc/concat, cls_conf_final/Softmax, predictions/concat/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# b'book 1.00' 40 6 114 69
# <class 'PIL.Image.Image'>

# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred import SSD
import matplotlib.pyplot as plt


if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    # dir_origin_path= "img/"  # 指定了用于检测的图片的文件夹路径
    # dir_save_path = "img_out/"  # 指定了检测完图片的保存路径
    # pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/hand/VOCdevkit/VOC2007/JPEGImages/230315_153921_00145.jpg"
    # pred_img_path = "/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand/img/240719_103320_00000slice.png"
    pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/VOCdevkit/VOC2007/JPEGImages/240809_151110_00121.png"
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            # r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()
# Out:
# 2024-08-10 12:40:23.833501: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-10 12:40:23.861880: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-10 12:40:23.862345: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-10 12:40:24.570331: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-08-10 12:40:26.583736: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2024-08-10 12:40:26.652905: W tensorflow/c/c_api.cc:304] Operation '{name:'Conv2D_conf_DD5_2/kernel/Assign' id:1509 op device:{requested: '', assigned: ''} def:{{{node Conv2D_conf_DD5_2/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](Conv2D_conf_DD5_2/kernel, Conv2D_conf_DD5_2/kernel/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen_2/20240810_pc_screen_3_another_init.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen_2/20240810_pc_screen_3_another_init.h5|
# |             classes_path | /home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/voc_classes.txt|
# |              input_shape |                               [120, 160]|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |              [32, 59, 86, 113, 141, 168]|
# |          letterbox_image |                                    False|
# ----------------------------------------------------------------------
# b'pc_screen 1.00' 31 29 107 159
# <class 'PIL.PngImagePlugin.PngImageFile'>
# /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-08-10 12:40:26.825948: W tensorflow/c/c_api.cc:304] Operation '{name:'predictions/concat' id:1602 op device:{requested: '', assigned: ''} def:{{{node predictions/concat}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32, _has_manual_control_dependencies=true](mbox_loc_final/Reshape, cls_conf_final/Softmax, predictions/concat/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred_tflite import SSD
import matplotlib.pyplot as plt

if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    pred_img_path = f"/home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/VOCdevkit/VOC2007/JPEGImages/240809_151110_00121.png"
    # pred_img_path = f"/home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/VOCdevkit/VOC2007/JPEGImages/240809_150811_00000.png"
    # pred_img_path = f"/home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/VOCdevkit/VOC2007/JPEGImages/240809_150814_00004.png"
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()
# Out:
# 2024-08-29 18:52:49.626175: W tensorflow/c/c_api.cc:304] Operation '{name:'Conv2D_loc_DD3_2_2/bias/Assign' id:5506 op device:{requested: '', assigned: ''} def:{{{node Conv2D_loc_DD3_2_2/bias/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](Conv2D_loc_DD3_2_2/bias, Conv2D_loc_DD3_2_2/bias/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand_yxhw_third_screen/output/pc_screen/20240810_pc_screen.h5|
# |             classes_path | /home/zhangyouan/桌面/zya/dataset/681/PC_Screen_D/voc_classes.txt|
# |              input_shape |                               [120, 160]|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |              [32, 59, 86, 113, 141, 168]|
# |          letterbox_image |                                    False|
# ----------------------------------------------------------------------
# b'pc_screen 1.00' 31 32 108 153
# <class 'PIL.PngImagePlugin.PngImageFile'>
# /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-08-29 18:52:49.892541: W tensorflow/c/c_api.cc:304] Operation '{name:'predictions_2/concat' id:5768 op device:{requested: '', assigned: ''} def:{{{node predictions_2/concat}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32, _has_manual_control_dependencies=true](mbox_loc_final_2/Reshape, cls_conf_final_2/Softmax, predictions_2/concat/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred import SSD
import matplotlib.pyplot as plt

if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    pred_img_path = "/home/zhangyouan/桌面/zya/dataset/681/good/VOCdevkit/VOC2007/JPEGImages/230317_111146_00616.jpg"
    
    # if mode == "predict":
    #     img = pred_img_path
    #     try:
    #         image = Image.open(img)
    #     except:
    #         print('Open Error! Try again!')
    #     else:
    #         r_image = ssd.detect_image(image, crop=crop, count=count)
    #         r_image.show()
    #         r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
    
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            print(type(r_image))
            img = cv2.cvtColor(np.asarray(r_image),cv2.COLOR_BGR2RGB)
            # rgb_image = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
            # r_image.show()
            r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            # plt.imshow(r_image)
            plt.imshow(img)
            plt.show()
# Out:
# 2024-07-08 16:18:44.156077: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-08 16:18:44.183672: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-07-08 16:18:44.184261: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-08 16:18:44.924588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-08 16:18:46.960874: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:375] MLIR V1 optimization pass is not enabled
# 2024-07-08 16:18:47.028816: W tensorflow/c/c_api.cc:304] Operation '{name:'Conv2D_loc_DD5_2/kernel/Assign' id:1567 op device:{requested: '', assigned: ''} def:{{{node Conv2D_loc_DD5_2/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](Conv2D_loc_DD5_2/kernel, Conv2D_loc_DD5_2/kernel/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand/output/1227/20240708_command.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback_1227hand/output/1227/20240708_command.h5|
# |             classes_path | /home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/VOC_dataset/voc_classes.txt|
# |              input_shape |                               [120, 160]|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |              [32, 59, 86, 113, 141, 168]|
# |          letterbox_image |                                    False|
# ----------------------------------------------------------------------
# b'good 1.00' 11 50 45 76
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2024-07-08 16:18:47.201099: W tensorflow/c/c_api.cc:304] Operation '{name:'predictions/concat' id:1602 op device:{requested: '', assigned: ''} def:{{{node predictions/concat}} = ConcatV2[N=2, T=DT_FLOAT, Tidx=DT_INT32, _has_manual_control_dependencies=true](mbox_loc_final/Reshape, cls_conf_final/Softmax, predictions/concat/axis)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
