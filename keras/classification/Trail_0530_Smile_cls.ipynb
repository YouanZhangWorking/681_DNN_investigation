# %%
import sys
sys.path.append("./keras/classification/")

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  
from keras.preprocessing.image import ImageDataGenerator
from Models_verison2 import model_version2
from log_visualization_tool import visual_train
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam

# %%
def cls_model_build(data_path=r"/home/zhangyouan/桌面/zya/dataset/681/srp/RockSecissorsPaper_enlarge/", 
                    epoch=300, 
                    save_model_name = 'cls_model_0821.h5',
                    model_summary="True",
                    weights = None):
    
    model = model_version2()
    if weights is not None:
        model.load_weights(weights)
        
    test_data_path = data_path + "val"
    train_data_path = data_path + "train"
    validation_datagen = ImageDataGenerator(rescale=1. / 255)
    training_datagen = ImageDataGenerator(rescale=1. / 255,
                                          rotation_range=40, # 旋转范围
                                          width_shift_range=0.2, # 宽平移
                                          height_shift_range=0.2,# 高平移
                                          shear_range=0.2, # 剪切
                                          zoom_range=0.2, # 缩放
                                          horizontal_flip=True,
                                          fill_mode='nearest')
    
    training_generator = training_datagen.flow_from_directory(train_data_path,
                                                              target_size=(120, 160),
                                                              color_mode="grayscale",
                                                              class_mode='categorical')

    validation_generator = validation_datagen.flow_from_directory(test_data_path,
                                                                  target_size=(120, 160),
                                                                  color_mode="grayscale",
                                                                  class_mode='categorical')
    

    # 使用 ReduceLROnPlateau 回调函数
    adam = Adam(lr=0.01)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6)
    early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
    model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    #======== 模型训练 =========
    history = model.fit(
        training_generator,
        epochs = epoch,
        validation_data = validation_generator,
        callbacks=[reduce_lr, early_stopping]
    )

    model.save(save_model_name) # model 保存

    return history

# %%
if __name__ == "__main__":
    history = cls_model_build(data_path=r"/home/zhangyouan/桌面/zya/dataset/681/Smile_cls_det/Smile_cls/", 
                              epoch=100, 
                              save_model_name = './../../output/keras/cls/Trail_0530_Smile_cls.h5',
                              model_summary=False)
    visual_train(history)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 120, 160, 1)]        0         []
#
#  conv2d_10 (Conv2D)          (None, 120, 160, 3)          30        ['input_2[0][0]']
#
#  depthwise_conv2d_9 (Depthw  (None, 120, 160, 3)          30        ['conv2d_10[0][0]']
#  iseConv2D)
#
#  conv2d_11 (Conv2D)          (None, 120, 160, 16)         64        ['depthwise_conv2d_9[0][0]']
#
#  depthwise_conv2d_10 (Depth  (None, 60, 80, 16)           160       ['conv2d_11[0][0]']
#  wiseConv2D)
#
#  conv2d_12 (Conv2D)          (None, 60, 80, 16)           448       ['conv2d_10[0][0]']
#
#  add_4 (Add)                 (None, 60, 80, 16)           0         ['depthwise_conv2d_10[0][0]',
#                                                                      'conv2d_12[0][0]']
#
#  re_lu_4 (ReLU)              (None, 60, 80, 16)           0         ['add_4[0][0]']
#
#  depthwise_conv2d_11 (Depth  (None, 30, 40, 16)           160       ['re_lu_4[0][0]']
#  wiseConv2D)
#
#  conv2d_13 (Conv2D)          (None, 30, 40, 32)           544       ['depthwise_conv2d_11[0][0]']
#
#  depthwise_conv2d_12 (Depth  (None, 30, 40, 32)           320       ['conv2d_13[0][0]']
#  wiseConv2D)
#
#  conv2d_14 (Conv2D)          (None, 30, 40, 32)           1056      ['depthwise_conv2d_12[0][0]']
#
#  depthwise_conv2d_13 (Depth  (None, 15, 20, 32)           320       ['conv2d_14[0][0]']
#  wiseConv2D)
#
#  conv2d_15 (Conv2D)          (None, 15, 20, 32)           9248      ['conv2d_13[0][0]']
#
#  batch_normalization_7 (Bat  (None, 15, 20, 32)           128       ['depthwise_conv2d_13[0][0]']
#  chNormalization)
#
#  batch_normalization_8 (Bat  (None, 15, 20, 32)           128       ['conv2d_15[0][0]']
#  chNormalization)
#
#  add_5 (Add)                 (None, 15, 20, 32)           0         ['batch_normalization_7[0][0]'
#                                                                     , 'batch_normalization_8[0][0]
#                                                                     ']
#
#  re_lu_5 (ReLU)              (None, 15, 20, 32)           0         ['add_5[0][0]']
#
#  depthwise_conv2d_14 (Depth  (None, 15, 20, 32)           320       ['re_lu_5[0][0]']
#  wiseConv2D)
#
#  conv2d_16 (Conv2D)          (None, 15, 20, 32)           1056      ['depthwise_conv2d_14[0][0]']
#
#  depthwise_conv2d_15 (Depth  (None, 8, 10, 32)            320       ['conv2d_16[0][0]']
#  wiseConv2D)
#
#  conv2d_17 (Conv2D)          (None, 8, 10, 32)            9248      ['re_lu_5[0][0]']
#
#  batch_normalization_9 (Bat  (None, 8, 10, 32)            128       ['depthwise_conv2d_15[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 8, 10, 32)            128       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 8, 10, 32)            0         ['batch_normalization_9[0][0]'
#                                                                     , 'batch_normalization_10[0][0
#                                                                     ]']
#
#  re_lu_6 (ReLU)              (None, 8, 10, 32)            0         ['add_6[0][0]']
#
#  depthwise_conv2d_16 (Depth  (None, 8, 10, 32)            320       ['re_lu_6[0][0]']
#  wiseConv2D)
#
#  conv2d_18 (Conv2D)          (None, 8, 10, 32)            1056      ['depthwise_conv2d_16[0][0]']
#
#  depthwise_conv2d_17 (Depth  (None, 4, 5, 32)             320       ['conv2d_18[0][0]']
#  wiseConv2D)
#
#  conv2d_19 (Conv2D)          (None, 4, 5, 32)             9248      ['re_lu_6[0][0]']
#
#  batch_normalization_11 (Ba  (None, 4, 5, 32)             128       ['depthwise_conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 4, 5, 32)             128       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 4, 5, 32)             0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  re_lu_7 (ReLU)              (None, 4, 5, 32)             0         ['add_7[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 2, 2, 32)             0         ['re_lu_7[0][0]']
#  g2D)
#
#  flatten_1 (Flatten)         (None, 128)                  0         ['max_pooling2d_1[0][0]']
#
#  dense_2 (Dense)             (None, 64)                   8256      ['flatten_1[0][0]']
#
#  batch_normalization_13 (Ba  (None, 64)                   256       ['dense_2[0][0]']
#  tchNormalization)
#
#  dense_3 (Dense)             (None, 2)                    130       ['batch_normalization_13[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 43678 (170.62 KB)
# Trainable params: 43166 (168.62 KB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________
# Found 366 images belonging to 2 classes.
# Found 31 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/100
# 12/12 [==============================] - 4s 104ms/step - loss: 0.8708 - accuracy: 0.5000 - val_loss: 0.6979 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 2/100
# 12/12 [==============================] - 1s 85ms/step - loss: 0.7561 - accuracy: 0.5546 - val_loss: 0.6996 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 3/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.7356 - accuracy: 0.5601 - val_loss: 0.6971 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 4/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.7103 - accuracy: 0.5874 - val_loss: 0.6969 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 5/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6679 - accuracy: 0.6148 - val_loss: 0.6993 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 6/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6870 - accuracy: 0.5683 - val_loss: 0.7003 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 7/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6496 - accuracy: 0.6038 - val_loss: 0.6997 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 8/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6425 - accuracy: 0.6148 - val_loss: 0.6996 - val_accuracy: 0.5161 - lr: 0.0010
# Epoch 9/100
# 12/12 [==============================] - 1s 92ms/step - loss: 0.6459 - accuracy: 0.6175 - val_loss: 0.7021 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 10/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6690 - accuracy: 0.5765 - val_loss: 0.7076 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 11/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6560 - accuracy: 0.6475 - val_loss: 0.7204 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 12/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6136 - accuracy: 0.6503 - val_loss: 0.7392 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 13/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6154 - accuracy: 0.6339 - val_loss: 0.7462 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 14/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6387 - accuracy: 0.6257 - val_loss: 0.7739 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 15/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6455 - accuracy: 0.5929 - val_loss: 0.8194 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 16/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5967 - accuracy: 0.6475 - val_loss: 0.8592 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 17/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5896 - accuracy: 0.6639 - val_loss: 0.8977 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 18/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6137 - accuracy: 0.6530 - val_loss: 0.9232 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 19/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.5945 - accuracy: 0.6557 - val_loss: 0.9803 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 20/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5674 - accuracy: 0.6913 - val_loss: 1.0196 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 21/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5946 - accuracy: 0.6694 - val_loss: 1.0354 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 22/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5824 - accuracy: 0.6694 - val_loss: 1.1075 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 23/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5502 - accuracy: 0.6995 - val_loss: 1.1693 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 24/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.5597 - accuracy: 0.6885 - val_loss: 1.2260 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 25/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.5053 - accuracy: 0.7240 - val_loss: 1.3434 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 26/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5229 - accuracy: 0.7240 - val_loss: 1.4216 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 27/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.5723 - accuracy: 0.6831 - val_loss: 1.4386 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 28/100
# 12/12 [==============================] - 1s 87ms/step - loss: 0.5439 - accuracy: 0.6721 - val_loss: 1.5651 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 29/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5165 - accuracy: 0.7268 - val_loss: 1.7344 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 30/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5106 - accuracy: 0.7268 - val_loss: 1.8236 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 31/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5324 - accuracy: 0.7268 - val_loss: 1.9205 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 32/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5005 - accuracy: 0.7158 - val_loss: 2.0592 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 33/100
# 12/12 [==============================] - 1s 86ms/step - loss: 0.5680 - accuracy: 0.7049 - val_loss: 2.1117 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 34/100
# 12/12 [==============================] - 1s 88ms/step - loss: 0.5040 - accuracy: 0.7486 - val_loss: 2.0061 - val_accuracy: 0.4839 - lr: 2.5000e-04
# /home/zhangyouan/anaconda3/envs/stc/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from Models_verison2 import model_version2_add_cls
from tensorflow.keras import layers, models
import tensorflow as tf


def cls_inc_model_bu(data_path=r"/home/zhangyouan/桌面/zya/dataset/681/srp/RockSecissorsPaper_for_incre_learning/Paper/", 
                    epoch=100, 
                    save_model_name = 'cls_model_1226.h5',
                    model_summary="True",
                    weights = None):
        
    test_data_path = data_path + "val"
    train_data_path = data_path + "train"
    validation_datagen = ImageDataGenerator(rescale=1. / 255)
    training_datagen = ImageDataGenerator(rescale=1. / 255,
                                          rotation_range=40, # 旋转范围
                                          width_shift_range=0.2, # 宽平移
                                          height_shift_range=0.2,# 高平移
                                          shear_range=0.2, # 剪切
                                          zoom_range=0.2, # 缩放
                                          horizontal_flip=True,
                                          fill_mode='nearest')
    
    training_generator = training_datagen.flow_from_directory(train_data_path,
                                                              target_size=(120, 160),
                                                              color_mode="grayscale",
                                                              class_mode='categorical')

    validation_generator = validation_datagen.flow_from_directory(test_data_path,
                                                                  target_size=(120, 160),
                                                                  color_mode="grayscale",
                                                                  class_mode='categorical')
    

    # 使用 ReduceLROnPlateau 回调函数
    adam = Adam(lr=0.01)
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6)
    early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)
    
    
    incremental_model = model_version2_add_cls(cls=2)
    for layer in incremental_model.layers:
        layer.trainable = False
        
    # 创建新的输出层
    new_output_layer1 = tf.keras.layers.Dense(64)(incremental_model.layers[-3].output)
    new_output_layer1 = tf.keras.layers.BatchNormalization()(new_output_layer1)
    new_output_layer2 = tf.keras.layers.Dense(1, activation='sigmoid')(new_output_layer1)
    incremental_model = models.Model(inputs = incremental_model.input, outputs=new_output_layer2)
    incremental_model.compile(optimizer = adam, loss = 'binary_crossentropy', metrics = ['accuracy'])
    
    #======== 模型训练 =========
    history = incremental_model.fit(
        training_generator,
        epochs = epoch,
        validation_data = validation_generator,
        callbacks=[reduce_lr, early_stopping]
    )

    incremental_model.save(save_model_name) # model 保存

    return history

if __name__ == "__main__":
    history = cls_model_build(data_path=r"/home/zhangyouan/桌面/zya/dataset/681/Smile_cls_det/Smile_cls/", 
                              epoch=500, 
                              save_model_name = './../../output/keras/cls/Trail_0530_Smile_cls_mnv2.h5',
                              model_summary=False)
    visual_train(history)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 120, 160, 1)]        0         []
#
#  conv2d_20 (Conv2D)          (None, 120, 160, 3)          30        ['input_3[0][0]']
#
#  depthwise_conv2d_18 (Depth  (None, 120, 160, 3)          30        ['conv2d_20[0][0]']
#  wiseConv2D)
#
#  conv2d_21 (Conv2D)          (None, 120, 160, 16)         64        ['depthwise_conv2d_18[0][0]']
#
#  depthwise_conv2d_19 (Depth  (None, 60, 80, 16)           160       ['conv2d_21[0][0]']
#  wiseConv2D)
#
#  conv2d_22 (Conv2D)          (None, 60, 80, 16)           448       ['conv2d_20[0][0]']
#
#  add_8 (Add)                 (None, 60, 80, 16)           0         ['depthwise_conv2d_19[0][0]',
#                                                                      'conv2d_22[0][0]']
#
#  re_lu_8 (ReLU)              (None, 60, 80, 16)           0         ['add_8[0][0]']
#
#  depthwise_conv2d_20 (Depth  (None, 30, 40, 16)           160       ['re_lu_8[0][0]']
#  wiseConv2D)
#
#  conv2d_23 (Conv2D)          (None, 30, 40, 32)           544       ['depthwise_conv2d_20[0][0]']
#
#  depthwise_conv2d_21 (Depth  (None, 30, 40, 32)           320       ['conv2d_23[0][0]']
#  wiseConv2D)
#
#  conv2d_24 (Conv2D)          (None, 30, 40, 32)           1056      ['depthwise_conv2d_21[0][0]']
#
#  depthwise_conv2d_22 (Depth  (None, 15, 20, 32)           320       ['conv2d_24[0][0]']
#  wiseConv2D)
#
#  conv2d_25 (Conv2D)          (None, 15, 20, 32)           9248      ['conv2d_23[0][0]']
#
#  batch_normalization_14 (Ba  (None, 15, 20, 32)           128       ['depthwise_conv2d_22[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 15, 20, 32)           128       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 15, 20, 32)           0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ']
#
#  re_lu_9 (ReLU)              (None, 15, 20, 32)           0         ['add_9[0][0]']
#
#  depthwise_conv2d_23 (Depth  (None, 15, 20, 32)           320       ['re_lu_9[0][0]']
#  wiseConv2D)
#
#  conv2d_26 (Conv2D)          (None, 15, 20, 32)           1056      ['depthwise_conv2d_23[0][0]']
#
#  depthwise_conv2d_24 (Depth  (None, 8, 10, 32)            320       ['conv2d_26[0][0]']
#  wiseConv2D)
#
#  conv2d_27 (Conv2D)          (None, 8, 10, 32)            9248      ['re_lu_9[0][0]']
#
#  batch_normalization_16 (Ba  (None, 8, 10, 32)            128       ['depthwise_conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 8, 10, 32)            128       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 8, 10, 32)            0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 8, 10, 32)            0         ['add_10[0][0]']
#
#  depthwise_conv2d_25 (Depth  (None, 8, 10, 32)            320       ['re_lu_10[0][0]']
#  wiseConv2D)
#
#  conv2d_28 (Conv2D)          (None, 8, 10, 32)            1056      ['depthwise_conv2d_25[0][0]']
#
#  depthwise_conv2d_26 (Depth  (None, 4, 5, 32)             320       ['conv2d_28[0][0]']
#  wiseConv2D)
#
#  conv2d_29 (Conv2D)          (None, 4, 5, 32)             9248      ['re_lu_10[0][0]']
#
#  batch_normalization_18 (Ba  (None, 4, 5, 32)             128       ['depthwise_conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 4, 5, 32)             128       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 4, 5, 32)             0         ['batch_normalization_18[0][0]
#                                                                     ',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  re_lu_11 (ReLU)             (None, 4, 5, 32)             0         ['add_11[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 32)             0         ['re_lu_11[0][0]']
#  g2D)
#
#  flatten_2 (Flatten)         (None, 128)                  0         ['max_pooling2d_2[0][0]']
#
#  dense_4 (Dense)             (None, 64)                   8256      ['flatten_2[0][0]']
#
#  batch_normalization_20 (Ba  (None, 64)                   256       ['dense_4[0][0]']
#  tchNormalization)
#
#  dense_5 (Dense)             (None, 2)                    130       ['batch_normalization_20[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 43678 (170.62 KB)
# Trainable params: 43166 (168.62 KB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________
# Found 366 images belonging to 2 classes.
# Found 31 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/500
# 12/12 [==============================] - 4s 106ms/step - loss: 0.8001 - accuracy: 0.4727 - val_loss: 0.6999 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 2/500
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6896 - accuracy: 0.5437 - val_loss: 0.7251 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 3/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6756 - accuracy: 0.6230 - val_loss: 0.7763 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 4/500
# 12/12 [==============================] - 1s 88ms/step - loss: 0.6765 - accuracy: 0.6148 - val_loss: 0.8524 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 5/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6700 - accuracy: 0.6202 - val_loss: 0.9610 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 6/500
# 12/12 [==============================] - 1s 88ms/step - loss: 0.6651 - accuracy: 0.6230 - val_loss: 1.0938 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 7/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6641 - accuracy: 0.6257 - val_loss: 1.2565 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 8/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6622 - accuracy: 0.6202 - val_loss: 1.4262 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 9/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6552 - accuracy: 0.6230 - val_loss: 1.6139 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 10/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6509 - accuracy: 0.6257 - val_loss: 1.9023 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 11/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6364 - accuracy: 0.6175 - val_loss: 2.2945 - val_accuracy: 0.4839 - lr: 0.0010
# Epoch 12/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6482 - accuracy: 0.6175 - val_loss: 2.7312 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 13/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6396 - accuracy: 0.6284 - val_loss: 3.1650 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 14/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6231 - accuracy: 0.6585 - val_loss: 3.6295 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 15/500
# 12/12 [==============================] - 1s 93ms/step - loss: 0.6470 - accuracy: 0.6366 - val_loss: 4.0814 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 16/500
# 12/12 [==============================] - 1s 93ms/step - loss: 0.6341 - accuracy: 0.6175 - val_loss: 4.5639 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 17/500
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6388 - accuracy: 0.6284 - val_loss: 5.1145 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 18/500
# 12/12 [==============================] - 1s 92ms/step - loss: 0.6338 - accuracy: 0.6148 - val_loss: 5.7284 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 19/500
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6469 - accuracy: 0.6148 - val_loss: 6.2464 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 20/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6377 - accuracy: 0.6175 - val_loss: 6.6864 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 21/500
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6310 - accuracy: 0.6038 - val_loss: 7.2119 - val_accuracy: 0.4839 - lr: 5.0000e-04
# Epoch 22/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6055 - accuracy: 0.6311 - val_loss: 7.8123 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 23/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6343 - accuracy: 0.6311 - val_loss: 8.4482 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 24/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6549 - accuracy: 0.6093 - val_loss: 9.0945 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 25/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6360 - accuracy: 0.6202 - val_loss: 9.6424 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 26/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6365 - accuracy: 0.6366 - val_loss: 10.3152 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 27/500
# 12/12 [==============================] - 1s 92ms/step - loss: 0.6177 - accuracy: 0.6448 - val_loss: 11.0396 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 28/500
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6087 - accuracy: 0.6421 - val_loss: 11.7879 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 29/500
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6032 - accuracy: 0.6858 - val_loss: 12.6802 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 30/500
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6217 - accuracy: 0.6366 - val_loss: 13.2723 - val_accuracy: 0.4839 - lr: 2.5000e-04
# Epoch 31/500
# 12/12 [==============================] - 1s 88ms/step - loss: 0.6669 - accuracy: 0.5765 - val_loss: 13.6601 - val_accuracy: 0.4839 - lr: 2.5000e-04
