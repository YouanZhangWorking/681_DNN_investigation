# %%
import time
import cv2
import numpy as np
from PIL import Image
from ssd_pred import SSD
import matplotlib.pyplot as plt


if __name__ == "__main__":
    ssd = SSD()
    mode = "predict" # or dir_predict  # dir predict用来预测文件夹，predict用来预测文件图片
    crop = False  # 指定了是否在单张图片预测后对目标进行截取
    count = False  # 指定了是否进行目标的计数
    # dir_origin_path= "img/"  # 指定了用于检测的图片的文件夹路径
    # dir_save_path = "img_out/"  # 指定了检测完图片的保存路径
    pred_img_path = r"C:\Users\5109I21112\Documents\clone\681_DNN_investigation\keras\detection\dataset\JPEGImages\230317_111251_00787.jpg"
    
    if mode == "predict":
        img = pred_img_path
        try:
            image = Image.open(img)
        except:
            print('Open Error! Try again!')
        else:
            r_image = ssd.detect_image(image, crop=crop, count=count)
            # r_image.show()
            # r_image.save("/home/zhangyouan/桌面/zya/NN_net/network/SSD/IMX_681_ssd_mobilenet_git/keras/detection/SSD_ipynb_transfer_callback/img_pred_output/img.jpg")
            plt.imshow(r_image)
            plt.show()
# Out:
# C:\Users\5109I21112\Documents\clone\681_DNN_investigation\keras\detection\SSD_ipynb_transfer_callback\output\20230819\good_detection_test_callback_2.h5 model, anchors, and classes loaded.
# Configurations:
# ----------------------------------------------------------------------
# |                     keys |                                   values|
# ----------------------------------------------------------------------
# |               model_path | C:\Users\5109I21112\Documents\clone\681_DNN_investigation\keras\detection\SSD_ipynb_transfer_callback\output\20230819\good_detection_test_callback_2.h5|
# |             classes_path | C:\Users\5109I21112\Documents\clone\681_DNN_investigation\keras\detection\SSD_ipynb_transfer_callback\output\20230819\voc_classes.txt|
# |              input_shape |                               [120, 160]|
# |               confidence |                                      0.5|
# |                  nms_iou |                                      0.3|
# |             anchors_size |              [32, 59, 86, 113, 141, 168]|
# |          letterbox_image |                                    False|
# ----------------------------------------------------------------------
# c:\Users\5109I21112\.conda\envs\phone\lib\site-packages\keras\src\engine\training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# ------ [[[ -4.2714667 -28.351183   -7.4340587   1.2105885   4.8021526
#     -7.994078 ]
#   [  1.5829077 -24.45809   -12.255405   -1.5486012   4.8045664
#     -7.9964924]
#   [ -5.3561926 -30.253378   -5.011677    7.995369    4.8065443
#     -7.998471 ]
#   ...
#   [ -1.3350701   2.7634773 -13.187523  -30.796415    4.761385
#     -7.95331  ]
#   [-14.744404  -19.100708    3.9651546 -18.48439     4.798314
#     -7.9902406]
#   [ -1.8094816   2.3084278  -6.4395113 -38.419247    4.745331
#     -7.9372563]]]
# ***** [[[ 0.1561515  -0.31230301 -0.23422725  0.39037876  1.40536353
#     0.31230301]
#   [-0.07807575  0.          1.01498477  1.48343928  1.40536353
#     0.31230301]
#   [-0.07807575 -0.93690902 -0.62460601  0.23422725  1.40536353
#     0.31230301]
#   ...
#   [ 2.34227255  1.71766654  1.01498477 -1.63959078  1.40536353
#     0.31230301]
#   [ 0.31230301  1.09306052  0.62460601  1.40536353  1.40536353
#     0.31230301]
#   [ 3.66956033  1.87381804  1.63959078 -2.5764998   1.40536353
#     0.31230301]]]
# b'good 1.41' 36 110 103 154
